# %% [markdown]
# # Lab 5: Value-Function Approximation
#
#
# ## Exercise 1 SGD
# Many real-world processes can be modeled as nonlinear relationships, and SGD is a standard tool to fit those models from data.
#
# **Example: Predicting energy consumption in a building**
# - Energy usage depends on **temperature**, **time of day**, and **occupancy**.
# - If you plot the data, the relationship might not be linear — it curves.
# - A simple way to approximate this nonlinear relation is to fit a **polynomial function** of temperature (or time).
#
# Now, imagine you’re collecting data continuously:
# - You get one data point (temperature, usage) at a time.
# - Instead of waiting to collect all data and computing a full batch update, you update your model incrementally with **SGD**.
# - This makes your learning **online, adaptive, and scalable** — just like in reinforcement learning.
#
# ---
#
# In this exercise, approximating a cubic polynomial is a simplified version of **predicting a nonlinear real-world phenomenon**.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data based on a cubic polynomial with Gaussian noise
np.random.seed(42)  # for reproducibility
n_samples = 100
x = np.linspace(-5, 5, n_samples)
# Define the true cubic polynomial function
def true_function(x):
  return 0.1 * x**3 - 0.5 * x**2 + 2 * x + 5

y_true = true_function(x)
noise = np.random.normal(0, 2, n_samples)  # Gaussian noise with mean 0 and std dev 2
y = y_true + noise

# Optional: Plot the generated data
plt.scatter(x, y, label='Generated Data')
plt.plot(x, y_true, color='red', label='True Function')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Generated Data with Cubic Polynomial and Gaussian Noise')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the given a dataset of input–output pairs `(x, y)` where the underlying relationship is approximately polynomial.
#
# a. Use a **linear model with polynomial features**: Write a function that takes an input `x` and a weight vector `w`, and return the predicted value y_hat.
#
#    - y_hat(x; w) = w0 + w1 * x + w2 * x^2 + w3 * x^3
#
#    where w0, w1, w2, w3 are the parameters to be learned.
#
# b. **Loss function (Mean Squared Error)**:
#    Write a function that computes the loss for one training point `(x, y)`:
#
#      - Formula: `loss = 0.5 * (y - y_hat)**2`
#
# c. **SGD update**:   Derive the gradient of the loss with respect to each parameter (w0, w1, w2, w3).
#    - Write a function:
#
#      ```python
#      def sgd_update(x, y, w, alpha):
#          """
#          Perform one SGD update for a single training example.
#          Input:
#              x (float) - input value
#              y (float) - true output
#              w (np.array) - current weights
#              alpha (float) - learning rate
#          Output:
#              w (np.array) - updated weights
#          """
#          # TODO: compute prediction, gradient, and update weights
#          return w
#      ```
# d. **Training loop**:
#    - Loop over the dataset.
#    - At each step, update the weights using `sgd_update`.
#    - Track the training loss after each iteration.
#
# e. **Comparison with different learning rates**
#    - Train your model using at least three different learning rates, for example:
#      - alpha = 0.001
#      - alpha = 0.01
#      - alpha = 0.1
#    - Plot training loss vs iteration for each learning rate.
#    - Plot the final fitted polynomial curves for each learning rate on the same graph with the true dataset.
#
# ---
#
# ### Deliverables
# - Code for `predict`, `mse_loss`, and `sgd_update`.
# - Training loop that runs with multiple learning rates.
# - Plot of training loss vs iteration for each learning rate.
# - Plot of the fitted polynomial vs dataset for each learning rate.
# - A short discussion:
#   - How does the learning rate affect convergence speed and stability?
#   - Which learning rate gives the best balance between speed and accuracy?

# %%
def predict(x, w):
    return w[0] + w[1] * x + w[2] * x**2 + w[3] * x**3

def mse_loss(x, y, w):
    y_hat = predict(x, w)
    return 0.5 * np.mean((y - y_hat)**2)


def sgd_update(x, y, w, alpha):
    """
    Perform one SGD update for a single training example.
    Input:
        x (float) - input value
        y (float) - true output
        w (np.array) - current weights
        alpha (float) - learning rate
    Output:
        w (np.array) - updated weights
    """
    # TODO: compute prediction, gradient, and update weights
    # Compute prediction
    y_hat = predict(x, w)
    error = y - y_hat
    grad = np.array([1, x, x**2, x**3])
    w = w + alpha * error * grad
    return w

# %%
def train_sgd(x, y, alpha, epochs=20):
    w = np.zeros(4)
    losses = []
    for epoch in range(epochs):
        for i in range(len(x)):
            w = sgd_update(x[i], y[i], w, alpha)
        losses.append(mse_loss(x, y, w))
    return w, losses

learning_rates = [0.0001, 0.00001, 0.000001]
results = {}

for alpha in learning_rates:
    w, losses = train_sgd(x, y, alpha, epochs=1000)
    results[alpha] = {"w": w, "losses": losses, "y_pred": predict(x, w)}


plt.figure(figsize=(10,5))
for alpha in learning_rates:
    plt.plot(results[alpha]["losses"], label=f"alpha={alpha}")
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error Loss")
plt.title("Training Loss vs Epoch")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.scatter(x, y, color="gray", alpha=0.6, label="Noisy Data")
plt.plot(x, y_true, color="red", linewidth=2, label="True Function")
for alpha in learning_rates:
    plt.plot(x, results[alpha]["y_pred"], label=f"Fitted (alpha={alpha})")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Final Fitted Curves for Different Learning Rates")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 2: 1000-State Random Walk with Semi-Gradient TD(0)
#
# We will study the 1,000-state Random Walk a classic reinforcement learning benchmark from Sutton & Barto.
#
# - The environment has states numbered **1 to 1000**.
# - There are two **terminal states**:
#   - State `0` on the left (reward = 0)
#   - State `1001` on the right (reward = 1)
# - Each episode starts in the **middle** at state `500`.
# - At each step, the agent moves **left or right with equal probability (0.5 each)**.
# - The episode ends when the agent reaches either terminal.
# - Discount factor: **γ = 1.0** (episodic task).
#
#
# ### Function Approximation
# Instead of storing a separate value for each state, approximate the value function with a **linear function of the state index**: V_hat(s; w0, w1) = w0 + w1 * s
#
#
#
# ---
#
# ## Instructions
# 1. **Implement the environment**:
#    - You may **use AI tools such as ChatGPT** to generate the environment code (states, transitions, rewards).
#    - Make sure you understand how the environment works.
#
# 2. **Implement the TD(0) update manually**:
#    - Do **not** use AI for this part.
#    - You must write the gradient update equations yourself using the formulas above.
#
# 3. **Train your agent**:
#    - Run several episodes (e.g., 1000 episodes).
#    - Experiment with different step sizes (`alpha`).
#
# 4. **Evaluate**:
#    - Plot the **true value function** `V*(s) = s/1001`.
#    - Plot your **learned approximation line** after training.
#    - Discuss whether the line captures the overall trend of the true values.
#
# ---
#
#
# ## Guidelines on Using AI Tools
# - You are encouraged to use AI tools (e.g., ChatGPT, Gemini, Copilot) to **generate helper code**, such as:
#   - Building the random walk environment (`reset`, `step`).
#   - Implementing the feature map φ(s).
#   - Plotting results.
# - However, **do not use AI tools to generate the TD(0) update equation**.
#   - Deriving and implementing the update is the key learning objective of this exercise.
#   - If we find code that uses an AI-generated update without understanding, the score will be zero.
#
#
# ## Deliverables
# - Python code for the environment and the TD(0) algorithm.
# - Plot the **true value function**: For state `s`, the probability of reaching the right terminal is:
#   `V*(s) = s / 1001`
# - Plot comparing the true value function and the approximated line.
# - A short discussion:
#   - How does the approximation behave for small vs large states?
#   - How does the learning rate affect convergence?
#
# ---
#
# ## Hints
# - Normalize states to `[0,1]` before using them in the line approximation to avoid very large values for w1.
# - Start with small step sizes (e.g., 0.001–0.01).
# - The approximation will not be perfect (a line cannot match the true curve), but should capture the increasing trend.

# %%
# import numpy as np
# import matplotlib.pyplot as plt
#
# class RandomWalk1000:
#     def __init__(self, n_states=1000):
#         self.n_states = n_states
#         self.start_state = n_states // 2
#         self.state = self.start_state
#
#     def reset(self):
#         self.state = self.start_state
#         return self.state
#
#     def step(self, action):
#         next_state = self.state + action
#         reward, done = 0, False
#         if next_state == 0:
#             done, reward = True, 0
#         elif next_state == self.n_states + 1:
#             done, reward = True, 1
#         self.state = next_state
#         return self.state, reward, done
#
#
# def td0_train(env, alpha=0.05, gamma=1.0, episodes=1000):
#     w = np.zeros(2)
#     mse = []
#     states = np.arange(1, env.n_states + 1)
#     V_true = states / (env.n_states + 1)
#
#     for ep in range(episodes):
#         s = env.reset()
#         done = False
#         steps = 0
#         while not done:
#             action = -1 if np.random.randint(2) == 0 else 1
#             s_next, reward, done = env.step(action)
#
#             phi_s = np.array([1.0, s / env.n_states])
#             v_s = np.dot(w, phi_s)
#
#             if done:
#                 target = reward
#             else:
#                 phi_next = np.array([1.0, s_next / env.n_states])
#                 v_next = np.dot(w, phi_next)
#                 target = reward + gamma * v_next
#
#             delta = target - v_s
#             w += alpha * delta * phi_s
#
#             s = s_next
#             steps += 1
#
#         V_hat = w[0] + w[1] * (states / env.n_states)
#         mse.append(np.mean((V_true - V_hat) ** 2))
#
#     return w, mse
#
#
# env = RandomWalk1000()
# learning_rates = [0.01]
# episodes = 700
# results = {}
#
# for alpha in learning_rates:
#     w, mse_history = td0_train(env, alpha=alpha, episodes=episodes)
#     states = np.arange(1, env.n_states + 1)
#     V_true = states / (env.n_states + 1)
#     V_hat = w[0] + w[1] * (states / env.n_states)
#     results[alpha] = {"w": w, "V_hat": V_hat, "V_true": V_true, "mse": mse_history}
#     print(f"alpha={alpha}, final weights={w}")
#
# plt.figure(figsize=(10,6))
# states = np.arange(1, env.n_states + 1)
# plt.plot(states, V_true, label="True Value Function", color="black", linewidth=2)
# for alpha in learning_rates:
#     plt.plot(states, results[alpha]["V_hat"], label=f"Estimated (alpha={alpha})")
# plt.xlabel("State")
# plt.ylabel("Value")
# plt.title("True vs Approximated Value Functions (Normalized Features)")
# plt.legend()
# plt.grid(True)
# plt.show()
#
# plt.figure(figsize=(10,6))
# for alpha in learning_rates:
#     plt.plot(np.arange(episodes), results[alpha]["mse"], label=f"alpha={alpha}")
# plt.xlabel("Episodes")
# plt.ylabel("MSE")
# plt.title("Convergence of Semi-Gradient TD(0) with Normalized Features")
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# # Exercise 3: Solving MountainCar with Tile Coding and SARSA
#
# ## Problem Description
# In this exercise, you will solve the **MountainCar-v0** environment from Gym using **tile coding** for function approximation and the **SARSA algorithm** for learning.
#
# The **Mountain Car problem**:
# - A car is stuck in a valley and is too weak to drive straight up to the goal.
# - It must build momentum by going back and forth until it can reach the goal at `position >= 0.5`.
# - **State space**: continuous (position, velocity).
# - **Actions**: {0: push left, 1: no push, 2: push right}.
# - **Reward**: -1 per step until the goal is reached.
# - **Episode ends**: when the car reaches the goal or after 200 steps.
#
# ---
#
# ## Step 1: Environment and Random Policy (with AI help)
# - Use an **AI tool (e.g., ChatGPT)** to generate starter code for:
#   - Creating the Gym environment (`MountainCar-v0`).
#   - Running a **random policy** (actions chosen randomly).
# - Run this code to confirm you can interact with the environment and see episode returns.
# - This will serve as a **baseline**.
# - **Important**: Do not use AI to implement the learning algorithm.
#
# ---
#
# ## Step 2: SARSA Algorithm with Function Approximation
# Implement **SARSA (on-policy TD control)** with the following steps:
#
# For each episode:
# 1. Initialize state `s`.
# 2. Choose action `a` using **ε-greedy** based on Q(s,a).
# 3. For each step:
#    - Take action `a`, observe `(s_next, r, done)`.
#    - Choose next action `a_next` using ε-greedy from `s_next`.
#    - Compute TD target:
#      ```
#      target = r + gamma * Q(s_next, a_next)
#      ```
#      (if `s_next` is terminal, then target = r).
#    - Compute TD error:
#      ```
#      delta = target - Q(s,a)
#      ```
#    - Update weights:
#      ```
#      w <- w + alpha * delta * x(s,a)
#      ```
#    - Update `s = s_next`, `a = a_next`.
# 4. End episode when the goal is reached or step limit is hit.
#
# ---
#
# ## Step 3: Experiments
# - Train the agent for 500–1000 episodes.
# - Plot **episode returns (sum of rewards)** vs episodes.
# - Compare with the random policy baseline:
#   - Does SARSA learn to consistently reach the goal?
#   - How many steps does it typically take?
#
# ---
#
# ## Deliverables
# - Python code for tile coding and SARSA.
# - Plot of returns vs episodes.
# - Plot the Value function
# - Short discussion (1–2 paragraphs):
#   - Effect of tile coding parameters (number of tilings, resolution).

# %%
# You can use the following code for tiling

import numpy as np
if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

class TileCoderXY:
    """
    A TileCoder for function approximation that applies tile coding on the x and y coordinates
    of a 3D state. Instead of providing tile widths, the user provides the number of tiles per
    dimension. The tile widths are computed based on the state bounds and the number of tiles.
    The z coordinate is not used.
    """

    def __init__(self, num_tilings, tiles_per_dim, state_low, state_high):
        """
        Initialize the TileCoderXY.

        Parameters:
            num_tilings (int): Number of overlapping tilings.
            tiles_per_dim (array-like of 2 ints): Number of tiles along the x and y dimensions.
            state_low (array-like of 2 floats): Lower bounds for the x and y dimensions.
            state_high (array-like of 2 floats): Upper bounds for the x and y dimensions.
        """
        self.num_tilings = num_tilings
        self.tiles_per_dim = np.array(tiles_per_dim, dtype=int)
        self.state_low = np.array(state_low, dtype=float)
        self.state_high = np.array(state_high, dtype=float)

        # Compute the tile width for each dimension.
        # We assume that the grid spans exactly from state_low to state_high.
        # When there are N tiles, there are N-1 intervals between the boundaries.
        self.tile_width = (self.state_high - self.state_low) / (self.tiles_per_dim - 1)

        # Precompute an offset for each tiling to create overlapping grids.
        # self.offsets = [(i / self.num_tilings) * self.tile_width for i in range(self.num_tilings)]
        # self.offsets = self.compute_8_offsets()
        # self.offsets = np.stack(self._compute_offsets(), axis=0)  # shape: (num_tilings, dims)
        # Precompute offsets for each tiling.
        # For tiling i:
        #   offset_x = (((i + 0) % num_tilings) / num_tilings) * tile_width[0]
        #   offset_y = (((i + 1) % num_tilings) / num_tilings) * tile_width[1]
        offsets = np.empty((self.num_tilings, 2))
        for i in range(self.num_tilings):
            offsets[i, 0] = (((i + 0) % self.num_tilings) / self.num_tilings) * self.tile_width[0]
            offsets[i, 1] = (((i + 1) % self.num_tilings) / self.num_tilings) * self.tile_width[1]
        self.offsets = offsets


        # Precompute multiplier for flattening a 2D index.
        # For grid shape (N, M), flat index = x_index * M + y_index.
        self.multiplier = self.tiles_per_dim[1]

        # Initialize a weight vector for each tiling.
        num_tiles = np.prod(self.tiles_per_dim)
        self.weights = [np.zeros(num_tiles) for _ in range(self.num_tilings)]

    def save(self, file_name):
        np.savez(file_name + ".npz", weights=self.weights)

    def load(self, file_name):
        self.weights = np.load(file_name+".npz")["weights"]


    def compute_8_offsets(self):
        """
        Compute a list of offsets using a combination of cardinal and diagonal directions.
        The offsets include:
          - Center: [0, 0]
          - Cardinal: right, left, up, down (half-tile shifts)
          - Diagonal: up-right, up-left, down-right, down-left (half-tile shifts)

        If the number of tilings exceeds the number of unique offsets (9), the list is repeated.

        Returns:
            List of 2-element numpy arrays representing the offset for each tiling.
        """
        half_tile = self.tile_width / 8.0
        base_offsets = [
            np.array([0.0, 0.0]),  # Center (no shift)
            np.array([half_tile[0], 0.0]),  # Right
            np.array([-half_tile[0], 0.0]),  # Left
            np.array([0.0, half_tile[1]]),  # Up
            np.array([0.0, -half_tile[1]]),  # Down
            np.array([half_tile[0], half_tile[1]]),  # Up-right
            np.array([-half_tile[0], half_tile[1]]),  # Up-left
            np.array([half_tile[0], -half_tile[1]]),  # Down-right
            np.array([-half_tile[0], -half_tile[1]])  # Down-left
        ]
        offsets = []
        for i in range(self.num_tilings):
            offsets.append(base_offsets[i % len(base_offsets)])
        return offsets

    def get_tile_indices(self, state):
        """
        Compute the active tile indices for all tilings given a 2D state.

        Parameters:
            state (array-like of length 2): The input state [x, y].

        Returns:
            List of tuples (tiling_index, flat_tile_index) for each tiling.
        """
        state = np.array(state, dtype=float)  # shape: (2,)
        # Compute shifted states for all tilings in one vectorized operation.
        # Shape of shifted: (num_tilings, 2)
        shifted = (state - self.state_low) + self.offsets

        # Compute tile coordinates (integer indices) for each tiling.
        # Division is broadcasted over the offsets.
        tile_coords = (shifted / self.tile_width).astype(int)  # shape: (num_tilings, 2)

        # Clip to ensure indices are within bounds.
        tile_coords[:, 0] = np.clip(tile_coords[:, 0], 0, self.tiles_per_dim[0] - 1)
        tile_coords[:, 1] = np.clip(tile_coords[:, 1], 0, self.tiles_per_dim[1] - 1)

        # Compute flat indices for each tiling.
        # flat_index = x_index * (tiles_per_dim[1]) + y_index
        flat_indices = tile_coords[:, 0] * self.tiles_per_dim[1] + tile_coords[:, 1]

        # Return a list of (tiling_index, flat_index) tuples.
        return list(zip(range(self.num_tilings), flat_indices))


    def predict(self, state):
        """
        Compute the approximated function value for a given 3D state using tile coding on x and y.

        Parameters:
            state (array-like): The input state [x, y, z].

        Returns:
            float: The function approximation (sum of weights for the active tiles).
        """
        active_tiles = self.get_tile_indices(state)
        return sum(self.weights[tiling][idx] for tiling, idx in active_tiles)

    def update(self, state, target, alpha):
        """
        Update the weights given a state and target value.

        Parameters:
            state (array-like): The input state [x, y, z].
            target (float): The target function value.
            alpha (float): The overall learning rate.
        """
        prediction = self.predict(state)
        error = target - prediction
        # Distribute the learning rate equally among all tilings.
        alpha_per_tiling = alpha / self.num_tilings

        active_tiles = self.get_tile_indices(state)
        for tiling, idx in active_tiles:
            self.weights[tiling][idx] += alpha_per_tiling * error

# %%
import numpy as np
import gym
import matplotlib.pyplot as plt

if not hasattr(np, "bool8"):
    np.bool8 = np.bool_

env = gym.make("MountainCar-v0", render_mode="ansi")

num_episodes = 500
gamma = 0.99
alpha = 0.1
epsilon = 0.1

num_tilings = 8
tiles_per_dim = [8, 8]
state_low = env.observation_space.low
state_high = env.observation_space.high

q_functions = [TileCoderXY(num_tilings, tiles_per_dim, state_low, state_high)
               for _ in range(env.action_space.n)]

def epsilon_greedy(state, epsilon):
    if np.random.rand() < epsilon:
        return env.action_space.sample()
    values = [q.predict(state) for q in q_functions]
    return int(np.argmax(values))

# SARSA
returns = []

for ep in range(num_episodes):

    state, _ = env.reset()
    action = epsilon_greedy(state, epsilon)
    total_reward = 0
    done = False
    while not done:
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state, epsilon)


        if done:
            target = reward
        else:
            target = reward + gamma * q_functions[next_action].predict(next_state)
        prediction = q_functions[action].predict(state)

        delta = target - prediction
        q_functions[action].update(state, target, alpha)
        state, action = next_state, next_action
        total_reward += reward

    returns.append(total_reward)
    print(f"Episode {ep+1}, Return = {total_reward}")

# plot learning curve
plt.plot(returns)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("SARSA with Tile Coding on MountainCar")
plt.show()

print(f"max return over last 100 episodes: {np.max(returns[-100:])}")
# Out:
# Episode 1, Return = -200.0
# Episode 2, Return = -200.0
# Episode 3, Return = -200.0
# Episode 4, Return = -200.0
# Episode 5, Return = -200.0
# Episode 6, Return = -200.0
# Episode 7, Return = -200.0
# Episode 8, Return = -200.0
# Episode 9, Return = -200.0
# Episode 10, Return = -200.0
# Episode 11, Return = -200.0
# Episode 12, Return = -200.0
# Episode 13, Return = -200.0
# Episode 14, Return = -200.0
# Episode 15, Return = -200.0
# Episode 16, Return = -200.0
# Episode 17, Return = -200.0
# Episode 18, Return = -200.0
# Episode 19, Return = -200.0
# Episode 20, Return = -200.0
# Episode 21, Return = -200.0
# Episode 22, Return = -200.0
# Episode 23, Return = -200.0
# Episode 24, Return = -200.0
# Episode 25, Return = -200.0
# Episode 26, Return = -200.0
# Episode 27, Return = -200.0
# Episode 28, Return = -200.0
# Episode 29, Return = -200.0
# Episode 30, Return = -200.0
# Episode 31, Return = -200.0
# Episode 32, Return = -200.0
# Episode 33, Return = -200.0
# Episode 34, Return = -200.0
# Episode 35, Return = -200.0
# Episode 36, Return = -200.0
# Episode 37, Return = -200.0
# Episode 38, Return = -200.0
# Episode 39, Return = -200.0
# Episode 40, Return = -200.0
# Episode 41, Return = -200.0
# Episode 42, Return = -200.0
# Episode 43, Return = -200.0
# Episode 44, Return = -200.0
# Episode 45, Return = -200.0
# Episode 46, Return = -200.0
# Episode 47, Return = -200.0
# Episode 48, Return = -200.0
# Episode 49, Return = -200.0
# Episode 50, Return = -200.0
# Episode 51, Return = -200.0
# Episode 52, Return = -200.0
# Episode 53, Return = -200.0
# Episode 54, Return = -200.0
# Episode 55, Return = -200.0
# Episode 56, Return = -200.0
# Episode 57, Return = -200.0
# Episode 58, Return = -200.0
# Episode 59, Return = -200.0
# Episode 60, Return = -200.0
# Episode 61, Return = -200.0
# Episode 62, Return = -200.0
# Episode 63, Return = -200.0
# Episode 64, Return = -200.0
# Episode 65, Return = -200.0
# Episode 66, Return = -200.0
# Episode 67, Return = -200.0
# Episode 68, Return = -200.0
# Episode 69, Return = -200.0
# Episode 70, Return = -200.0
# Episode 71, Return = -200.0
# Episode 72, Return = -200.0
# Episode 73, Return = -200.0
# Episode 74, Return = -200.0
# Episode 75, Return = -200.0
# Episode 76, Return = -200.0
# Episode 77, Return = -200.0
# Episode 78, Return = -200.0
# Episode 79, Return = -200.0
# Episode 80, Return = -200.0
# Episode 81, Return = -200.0
# Episode 82, Return = -200.0
# Episode 83, Return = -200.0
# Episode 84, Return = -200.0
# Episode 85, Return = -193.0
# Episode 86, Return = -200.0
# Episode 87, Return = -200.0
# Episode 88, Return = -200.0
# Episode 89, Return = -200.0
# Episode 90, Return = -200.0
# Episode 91, Return = -200.0
# Episode 92, Return = -200.0
# Episode 93, Return = -200.0
# Episode 94, Return = -200.0
# Episode 95, Return = -156.0
# Episode 96, Return = -200.0
# Episode 97, Return = -200.0
# Episode 98, Return = -200.0
# Episode 99, Return = -200.0
# Episode 100, Return = -200.0
# Episode 101, Return = -200.0
# Episode 102, Return = -200.0
# Episode 103, Return = -200.0
# Episode 104, Return = -200.0
# Episode 105, Return = -171.0
# Episode 106, Return = -164.0
# Episode 107, Return = -167.0
# Episode 108, Return = -160.0
# Episode 109, Return = -172.0
# Episode 110, Return = -200.0
# Episode 111, Return = -200.0
# Episode 112, Return = -200.0
# Episode 113, Return = -166.0
# Episode 114, Return = -200.0
# Episode 115, Return = -200.0
# Episode 116, Return = -173.0
# Episode 117, Return = -165.0
# Episode 118, Return = -200.0
# Episode 119, Return = -200.0
# Episode 120, Return = -164.0
# Episode 121, Return = -154.0
# Episode 122, Return = -200.0
# Episode 123, Return = -200.0
# Episode 124, Return = -200.0
# Episode 125, Return = -200.0
# Episode 126, Return = -160.0
# Episode 127, Return = -200.0
# Episode 128, Return = -188.0
# Episode 129, Return = -198.0
# Episode 130, Return = -187.0
# Episode 131, Return = -166.0
# Episode 132, Return = -200.0
# Episode 133, Return = -168.0
# Episode 134, Return = -157.0
# Episode 135, Return = -186.0
# Episode 136, Return = -160.0
# Episode 137, Return = -200.0
# Episode 138, Return = -200.0
# Episode 139, Return = -200.0
# Episode 140, Return = -167.0
# Episode 141, Return = -161.0
# Episode 142, Return = -200.0
# Episode 143, Return = -200.0
# Episode 144, Return = -134.0
# Episode 145, Return = -178.0
# Episode 146, Return = -166.0
# Episode 147, Return = -200.0
# Episode 148, Return = -154.0
# Episode 149, Return = -200.0
# Episode 150, Return = -200.0
# Episode 151, Return = -163.0
# Episode 152, Return = -200.0
# Episode 153, Return = -159.0
# Episode 154, Return = -200.0
# Episode 155, Return = -170.0
# Episode 156, Return = -156.0
# Episode 157, Return = -160.0
# Episode 158, Return = -200.0
# Episode 159, Return = -168.0
# Episode 160, Return = -173.0
# Episode 161, Return = -156.0
# Episode 162, Return = -165.0
# Episode 163, Return = -160.0
# Episode 164, Return = -166.0
# Episode 165, Return = -152.0
# Episode 166, Return = -200.0
# Episode 167, Return = -125.0
# Episode 168, Return = -200.0
# Episode 169, Return = -158.0
# Episode 170, Return = -200.0
# Episode 171, Return = -200.0
# Episode 172, Return = -200.0
# Episode 173, Return = -200.0
# Episode 174, Return = -200.0
# Episode 175, Return = -191.0
# Episode 176, Return = -168.0
# Episode 177, Return = -198.0
# Episode 178, Return = -165.0
# Episode 179, Return = -161.0
# Episode 180, Return = -200.0
# Episode 181, Return = -200.0
# Episode 182, Return = -200.0
# Episode 183, Return = -167.0
# Episode 184, Return = -197.0
# Episode 185, Return = -200.0
# Episode 186, Return = -200.0
# Episode 187, Return = -200.0
# Episode 188, Return = -200.0
# Episode 189, Return = -171.0
# Episode 190, Return = -194.0
# Episode 191, Return = -156.0
# Episode 192, Return = -186.0
# Episode 193, Return = -188.0
# Episode 194, Return = -156.0
# Episode 195, Return = -157.0
# Episode 196, Return = -157.0
# Episode 197, Return = -160.0
# Episode 198, Return = -195.0
# Episode 199, Return = -200.0
# Episode 200, Return = -200.0
# Episode 201, Return = -199.0
# Episode 202, Return = -200.0
# Episode 203, Return = -177.0
# Episode 204, Return = -159.0
# Episode 205, Return = -156.0
# Episode 206, Return = -200.0
# Episode 207, Return = -200.0
# Episode 208, Return = -158.0
# Episode 209, Return = -198.0
# Episode 210, Return = -173.0
# Episode 211, Return = -119.0
# Episode 212, Return = -116.0
# Episode 213, Return = -196.0
# Episode 214, Return = -147.0
# Episode 215, Return = -156.0
# Episode 216, Return = -200.0
# Episode 217, Return = -197.0
# Episode 218, Return = -120.0
# Episode 219, Return = -200.0
# Episode 220, Return = -200.0
# Episode 221, Return = -157.0
# Episode 222, Return = -170.0
# Episode 223, Return = -200.0
# Episode 224, Return = -121.0
# Episode 225, Return = -120.0
# Episode 226, Return = -200.0
# Episode 227, Return = -200.0
# Episode 228, Return = -116.0
# Episode 229, Return = -168.0
# Episode 230, Return = -145.0
# Episode 231, Return = -156.0
# Episode 232, Return = -152.0
# Episode 233, Return = -152.0
# Episode 234, Return = -156.0
# Episode 235, Return = -122.0
# Episode 236, Return = -158.0
# Episode 237, Return = -133.0
# Episode 238, Return = -113.0
# Episode 239, Return = -114.0
# Episode 240, Return = -188.0
# Episode 241, Return = -157.0
# Episode 242, Return = -200.0
# Episode 243, Return = -200.0
# Episode 244, Return = -160.0
# Episode 245, Return = -153.0
# Episode 246, Return = -200.0
# Episode 247, Return = -181.0
# Episode 248, Return = -152.0
# Episode 249, Return = -133.0
# Episode 250, Return = -200.0
# Episode 251, Return = -196.0
# Episode 252, Return = -192.0
# Episode 253, Return = -156.0
# Episode 254, Return = -120.0
# Episode 255, Return = -199.0
# Episode 256, Return = -123.0
# Episode 257, Return = -155.0
# Episode 258, Return = -184.0
# Episode 259, Return = -200.0
# Episode 260, Return = -128.0
# Episode 261, Return = -187.0
# Episode 262, Return = -196.0
# Episode 263, Return = -166.0
# Episode 264, Return = -156.0
# Episode 265, Return = -146.0
# Episode 266, Return = -152.0
# Episode 267, Return = -144.0
# Episode 268, Return = -187.0
# Episode 269, Return = -160.0
# Episode 270, Return = -157.0
# Episode 271, Return = -155.0
# Episode 272, Return = -153.0
# Episode 273, Return = -147.0
# Episode 274, Return = -165.0
# Episode 275, Return = -150.0
# Episode 276, Return = -200.0
# Episode 277, Return = -200.0
# Episode 278, Return = -184.0
# Episode 279, Return = -149.0
# Episode 280, Return = -170.0
# Episode 281, Return = -123.0
# Episode 282, Return = -156.0
# Episode 283, Return = -155.0
# Episode 284, Return = -121.0
# Episode 285, Return = -151.0
# Episode 286, Return = -159.0
# Episode 287, Return = -159.0
# Episode 288, Return = -126.0
# Episode 289, Return = -155.0
# Episode 290, Return = -158.0
# Episode 291, Return = -151.0
# Episode 292, Return = -153.0
# Episode 293, Return = -127.0
# Episode 294, Return = -184.0
# Episode 295, Return = -200.0
# Episode 296, Return = -161.0
# Episode 297, Return = -159.0
# Episode 298, Return = -147.0
# Episode 299, Return = -157.0
# Episode 300, Return = -156.0
# Episode 301, Return = -192.0
# Episode 302, Return = -189.0
# Episode 303, Return = -149.0
# Episode 304, Return = -147.0
# Episode 305, Return = -154.0
# Episode 306, Return = -147.0
# Episode 307, Return = -111.0
# Episode 308, Return = -188.0
# Episode 309, Return = -117.0
# Episode 310, Return = -185.0
# Episode 311, Return = -151.0
# Episode 312, Return = -149.0
# Episode 313, Return = -143.0
# Episode 314, Return = -159.0
# Episode 315, Return = -128.0
# Episode 316, Return = -145.0
# Episode 317, Return = -114.0
# Episode 318, Return = -119.0
# Episode 319, Return = -152.0
# Episode 320, Return = -200.0
# Episode 321, Return = -120.0
# Episode 322, Return = -112.0
# Episode 323, Return = -173.0
# Episode 324, Return = -152.0
# Episode 325, Return = -164.0
# Episode 326, Return = -151.0
# Episode 327, Return = -155.0
# Episode 328, Return = -151.0
# Episode 329, Return = -140.0
# Episode 330, Return = -155.0
# Episode 331, Return = -144.0
# Episode 332, Return = -156.0
# Episode 333, Return = -149.0
# Episode 334, Return = -144.0
# Episode 335, Return = -138.0
# Episode 336, Return = -156.0
# Episode 337, Return = -95.0
# Episode 338, Return = -151.0
# Episode 339, Return = -119.0
# Episode 340, Return = -151.0
# Episode 341, Return = -114.0
# Episode 342, Return = -153.0
# Episode 343, Return = -123.0
# Episode 344, Return = -162.0
# Episode 345, Return = -160.0
# Episode 346, Return = -151.0
# Episode 347, Return = -137.0
# Episode 348, Return = -154.0
# Episode 349, Return = -188.0
# Episode 350, Return = -160.0
# Episode 351, Return = -159.0
# Episode 352, Return = -136.0
# Episode 353, Return = -196.0
# Episode 354, Return = -154.0
# Episode 355, Return = -183.0
# Episode 356, Return = -116.0
# Episode 357, Return = -162.0
# Episode 358, Return = -156.0
# Episode 359, Return = -116.0
# Episode 360, Return = -153.0
# Episode 361, Return = -162.0
# Episode 362, Return = -149.0
# Episode 363, Return = -113.0
# Episode 364, Return = -166.0
# Episode 365, Return = -167.0
# Episode 366, Return = -145.0
# Episode 367, Return = -178.0
# Episode 368, Return = -154.0
# Episode 369, Return = -200.0
# Episode 370, Return = -161.0
# Episode 371, Return = -137.0
# Episode 372, Return = -119.0
# Episode 373, Return = -158.0
# Episode 374, Return = -150.0
# Episode 375, Return = -120.0
# Episode 376, Return = -161.0
# Episode 377, Return = -157.0
# Episode 378, Return = -154.0
# Episode 379, Return = -162.0
# Episode 380, Return = -152.0
# Episode 381, Return = -147.0
# Episode 382, Return = -157.0
# Episode 383, Return = -161.0
# Episode 384, Return = -148.0
# Episode 385, Return = -155.0
# Episode 386, Return = -148.0
# Episode 387, Return = -141.0
# Episode 388, Return = -113.0
# Episode 389, Return = -118.0
# Episode 390, Return = -170.0
# Episode 391, Return = -153.0
# Episode 392, Return = -117.0
# Episode 393, Return = -166.0
# Episode 394, Return = -149.0
# Episode 395, Return = -157.0
# Episode 396, Return = -122.0
# Episode 397, Return = -127.0
# Episode 398, Return = -151.0
# Episode 399, Return = -131.0
# Episode 400, Return = -147.0
# Episode 401, Return = -115.0
# Episode 402, Return = -161.0
# Episode 403, Return = -151.0
# Episode 404, Return = -153.0
# Episode 405, Return = -157.0
# Episode 406, Return = -151.0
# Episode 407, Return = -154.0
# Episode 408, Return = -153.0
# Episode 409, Return = -151.0
# Episode 410, Return = -156.0
# Episode 411, Return = -146.0
# Episode 412, Return = -152.0
# Episode 413, Return = -153.0
# Episode 414, Return = -152.0
# Episode 415, Return = -94.0
# Episode 416, Return = -158.0
# Episode 417, Return = -148.0
# Episode 418, Return = -150.0
# Episode 419, Return = -141.0
# Episode 420, Return = -162.0
# Episode 421, Return = -147.0
# Episode 422, Return = -121.0
# Episode 423, Return = -146.0
# Episode 424, Return = -150.0
# Episode 425, Return = -152.0
# Episode 426, Return = -165.0
# Episode 427, Return = -142.0
# Episode 428, Return = -153.0
# Episode 429, Return = -151.0
# Episode 430, Return = -149.0
# Episode 431, Return = -140.0
# Episode 432, Return = -168.0
# Episode 433, Return = -144.0
# Episode 434, Return = -121.0
# Episode 435, Return = -145.0
# Episode 436, Return = -147.0
# Episode 437, Return = -154.0
# Episode 438, Return = -168.0
# Episode 439, Return = -149.0
# Episode 440, Return = -123.0
# Episode 441, Return = -118.0
# Episode 442, Return = -156.0
# Episode 443, Return = -148.0
# Episode 444, Return = -155.0
# Episode 445, Return = -149.0
# Episode 446, Return = -148.0
# Episode 447, Return = -114.0
# Episode 448, Return = -148.0
# Episode 449, Return = -160.0
# Episode 450, Return = -146.0
# Episode 451, Return = -115.0
# Episode 452, Return = -155.0
# Episode 453, Return = -154.0
# Episode 454, Return = -117.0
# Episode 455, Return = -150.0
# Episode 456, Return = -151.0
# Episode 457, Return = -150.0
# Episode 458, Return = -147.0
# Episode 459, Return = -159.0
# Episode 460, Return = -113.0
# Episode 461, Return = -163.0
# Episode 462, Return = -156.0
# Episode 463, Return = -128.0
# Episode 464, Return = -163.0
# Episode 465, Return = -151.0
# Episode 466, Return = -148.0
# Episode 467, Return = -154.0
# Episode 468, Return = -148.0
# Episode 469, Return = -127.0
# Episode 470, Return = -121.0
# Episode 471, Return = -115.0
# Episode 472, Return = -121.0
# Episode 473, Return = -116.0
# Episode 474, Return = -114.0
# Episode 475, Return = -160.0
# Episode 476, Return = -156.0
# Episode 477, Return = -114.0
# Episode 478, Return = -118.0
# Episode 479, Return = -155.0
# Episode 480, Return = -119.0
# Episode 481, Return = -117.0
# Episode 482, Return = -142.0
# Episode 483, Return = -155.0
# Episode 484, Return = -134.0
# Episode 485, Return = -154.0
# Episode 486, Return = -152.0
# Episode 487, Return = -200.0
# Episode 488, Return = -120.0
# Episode 489, Return = -150.0
# Episode 490, Return = -147.0
# Episode 491, Return = -151.0
# Episode 492, Return = -115.0
# Episode 493, Return = -149.0
# Episode 494, Return = -144.0
# Episode 495, Return = -153.0
# Episode 496, Return = -146.0
# Episode 497, Return = -145.0
# Episode 498, Return = -145.0
# Episode 499, Return = -153.0
# Episode 500, Return = -146.0
# max return over last 100 episodes: -94.0
